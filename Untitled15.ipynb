# %% [markdown]
# <a href="https://colab.research.google.com/github/tharuniganapthi/external-projects/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>Portfolio</title>
<link
href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&family=Montserrat:
wght@300;500&display=swap" rel="stylesheet">
<style>
body, h1, h2, h3, p, ul, li, form, input, textarea {
margin: 0;
padding: 0;
box-sizing: border-box;
}
body {
font-family: 'Roboto', sans-serif;
line-height: 1.6;
color: #827979;
background: #f4f4f4;
}
header {
position: relative;
overflow: hidden;
}
header::before {
content: '';
position: absolute;
top: 0;
left: 0;
width: 100%;
height: 100%;
background: rgba(0, 0, 0, 0.4);
z-index: 1;
}
nav {
background-color: rgba(0, 0, 0, 0.6);
      width: 100%;
padding: 1rem;
position: fixed;
top: 0;
left: 0;
z-index: 3;
}
nav ul {
list-style: none;
padding: 0;
display: flex;
justify-content: center;
}
nav ul li {
margin: 0 15px;
}
nav ul li a {
color: #fff;
text-decoration: none;
font-weight: bold;
font-family: 'Montserrat', sans-serif;
transition: color 0.3s;
}
nav ul li a:hover {
color: #e9705b;
}
.hero {
position: relative;
z-index: 2;
height: 100vh;
display: flex;
flex-direction: column;
align-items: center;
        justify-content: center;
color: #fff;
text-align: center;
}
.hero video {
position: absolute;
top: 0;
left: 0;
width: 100%;
height: 100%;
object-fit: cover;
z-index: 0;
filter: brightness(0.7);
}
.hero h1 {
margin: 0;
font-size: 3rem;
font-family: 'Montserrat', sans-serif;
position: relative;
z-index: 3;
}
.hero p {
font-size: 1.5rem;
position: relative;
z-index: 3;
}
section {
padding: 1.5rem;
background: rgba(255, 255, 255, 0.9);
margin: 1rem 0;
border-radius: 15px;
box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
position: relative;
overflow: hidden;
}
h2 {
border-bottom: 2px solid #5a819b;
padding-bottom: 0.5rem;
margin-bottom: 1rem;
font-family: 'Montserrat', sans-serif;
color: #325871;
}
section::before {
content: '';
position: absolute;
top: -50px;
right: -50px;
width: 150px;
height: 150px;
background: rgba(255, 87, 34, 0.5);
border-radius: 50%;
z-index: -1;
opacity: 0.7;
transform: scale(0.9);
}
section:nth-of-type(2)::before {
background: rgba(76, 175, 80, 0.5);
                                 top: 50px;
left: -50px;
transform: scale(1.2);
}
section:nth-of-type(3)::before {
background: rgba(27, 94, 149, 0.5);
bottom: -50px;
right: 50px;
transform: scale(1.1);
}
#home, #about {
padding: 1rem;
margin: 1rem 0;
background: rgba(255, 255, 255, 0.8);
}
#home h2, #about h2 {
font-size: 2rem;
color: #0d598b;
}
#about p {
font-size: 1rem;
}
.grid {
display: flex;
gap: 1rem;
flex-wrap: wrap;
}
.card {
flex: 1;
min-width: calc(33% - 1rem);
background: #fff;
padding: 1rem;
        border-radius: 8px;
box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
transition: transform 0.3s, box-shadow 0.3s;
}
.card:hover {
transform: scale(1.05);
box-shadow: 0 6px 12px rgba(0, 0, 0, 0.2);
}
.card img {
width: 100%;
border-radius: 8px;
transition: opacity 0.3s;
}
.card:hover img {
opacity: 0.8;
}
.card h3 {
margin-top: 0.5rem;
font-size: 1.2rem;
font-family: 'Montserrat', sans-serif;
color: #053c61;
}
.card p {
font-size: 0.9rem;
}
form {
display: grid;
gap: 1rem;
}
form label {
display: block;
font-weight: bold;
             }
form input, form textarea {
width: 100%;
padding: 0.5rem;
border: 1px solid #ccc;
border-radius: 4px;
}
form button {
background: #1b317a;
color: #fff;
border: none;
padding: 0.5rem;
border-radius: 4px;
cursor: pointer;
transition: background 0.3s;
}
form button:hover {
    background: #44789a;
}
footer {
background: #333;
color: #fff;
text-align: center;
padding: 1rem 0;
}
@media only screen and (max-width: 768px) {
nav ul {
flex-direction: column;
}
.hero h1 {
font-size: 2rem;
}
.hero p {
font-size: 1rem;
}
.card {
min-width: calc(50% - 1rem);
}
}
@media only screen and (max-width: 480px) {
.card {
min-width: 100%;
}
}
</style>
</head>
<body>
<header>
<nav>
<ul>
<li><a href="#home">Home</a></li>
<li><a href="#about">About</a></li>
<li><a href="#portfolio">Portfolio</a></li>
<li><a href="#contact">Contact</a></li>
</ul>
</nav>
<div class="hero">
<video autoplay loop muted playsinline>
<source src="codeee.mp4" type="video/mp4">
Your browser does not support the video tag.
</video>
<h1>Welcome to My Portfolio</h1>
<p>Explore my work and experience!</p>
</div>
</header>
<section id="home">
<h2>Home</h2>
<p>Welcome to my personal portfolio website. <br> Scroll down to see more about me
and my work! Feel free to use them as references!</p>
</section>
<section id="about">
<h2>About Me</h2>
<p>
Hi, I'm an aspiring developer passionate about creating impactful solutions through
code.
With a keen interest in both front-end and back-end development, I am committed to
crafting seamless and user-friendly applications.
Constantly striving to learn, I embrace every opportunity to enhance my skills and
knowledge.
These projects have allowed me to apply my growing expertise in real-world
scenarios, including developing an AI-based voice bot for mock interviews and creating
interactive web applications.
I am eager to continue expanding my abilities, tackling new challenges, and
contributing to innovative solutions as I progress in my development journey.
I am still a beginner discovering the depths of this field and loving every step I've
taken in this journey.
I have only made two simple websites till now and looking forward to making more
as time passes by
</p>
</section>
<section id="portfolio">
<h2>Portfolio</h2>
<div class="grid">
<div class="card">
<h3>Project 1: AI-based Voice Bot for Mock Interviews</h3>
<img src="proj.jpg" alt="Picture 1">
<p>
For my AI-based voice bot project, I designed a user-friendly website using
HTML and CSS, emphasizing simplicity and clarity to ensure an intuitive user experience.
The project features a multi-faceted system: users start by uploading their
resumes in PDF format, which are parsed using a Hugging Face model to categorize skills
into soft and hard types.
The core functionality includes a mock interview simulation powered by a finetuned Cohere AI model, which interacts with users through speech recognition technology,
converting spoken responses into text and vice versa.
The entire interview is recorded, and subsequent analysis by another Cohere AI
instance provides personalized feedback on performance.
The website, built with Streamlit, seamlessly guides users through each step—
uploading resumes, participating in interviews, and receiving actionable feedback—without
adding unnecessary complexity.
This approach ensures that users can easily navigate and fully utilize the tool for
effective interview preparation.
</p>
</div>
<div class="card">
<h3>Project 2: Bank Management System using Java </h3>
<img src="Screenshot 2024-08-05 200541.png" alt="Picture 1">
<p>
As part of my development journey, I created a comprehensive bank
management system using Java, leveraging Swing and AWT components to build a robust
and interactive user interface.
This project involved designing a system to manage various banking operations,
including account creation, transaction processing, and balance management.
I utilized Java Swing for crafting the graphical user interface, enabling a userfriendly experience with features like menus, buttons, and dialogs.
Additionally, AWT components were employed to enhance the functionality and
responsiveness of the application.
Through this project, I gained valuable experience in Java programming, UI
design, and application development, providing a solid foundation for tackling more complex
challenges in the future.
</p>
</div>
</div>
</section>
<section id="contact">
<h2>Contact</h2>
<p>Feel free to reach out to me for any inquiries or collaborations.</p>
<form>
<label for="name">Name:</label>
<input type="text" id="name" name="name" required>
<label for="email">Email:</label>
<input type="email" id="email" name="email" required>
<label for="message">Message:</label>
<textarea id="message" name="message" required></textarea>
<button type="submit">Send</button>
</form>
</section>
<footer>
<p>&copy; 2024 Portfolio. All rights reserved.</p>
</footer>
</body>
</html>
